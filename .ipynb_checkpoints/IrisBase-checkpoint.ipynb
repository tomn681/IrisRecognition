# %% [markdown]
# ### Lectura Requerida:
#
# Parte 1a- Detección de Pupila, Canny's Algorithm and Image Gradient
#
#         https://www.researchgate.net/publication/267240432_Deteccion_de_bordes_mediante_el_algoritmo_de_Canny
#
#         https://en.wikipedia.org/wiki/Image_gradient
#
#     Paper : https://ieeexplore-ieee-org.uchile.idm.oclc.org/stamp/stamp.jsp?tp=&arnumber=6754895
#
# Parte 1b - Detección de Iris, Daugman's Iris Detection Algorithm
#
#         http://www.diva-portal.org/smash/get/diva2:831173/FULLTEXT01.pdf
#
#     Paper : https://ieeexplore-ieee-org.uchile.idm.oclc.org/stamp/stamp.jsp?tp=&arnumber=6116350
#
# Parte 2 -

# %% [markdown]
# ### Requirements

# %%
# !pip install opencv-python
# !pip install google.colab

# %% [markdown]
# ###Cargar Datos de Multimedia University (MMU1) database

# %%
from google.colab import files
uploaded = files.upload()

# %%
# !unzip /content/MMUIrisDatabase.zip
# Out:
# Archive:  /content/MMUIrisDatabase.zip
#    creating: /content/imagenes/MMU Iris Database/1/
#    creating: /content/imagenes/MMU Iris Database/1/left/
#   inflating: /content/imagenes/MMU Iris Database/1/left/aeval1.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/left/aeval2.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/left/aeval3.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/left/aeval4.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/left/aeval5.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/left/Thumbs.db
#    creating: /content/imagenes/MMU Iris Database/1/right/
#   inflating: /content/imagenes/MMU Iris Database/1/right/aevar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/right/aevar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/right/aevar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/right/aevar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/right/aevar5.bmp
#   inflating: /content/imagenes/MMU Iris Database/1/right/Thumbs.db
#    creating: /content/imagenes/MMU Iris Database/10/
#    creating: /content/imagenes/MMU Iris Database/10/left/
#   inflating: /content/imagenes/MMU Iris Database/10/left/fional1.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/left/fional2.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/left/fional3.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/left/fional4.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/left/fional5.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/left/Thumbs.db
#    creating: /content/imagenes/MMU Iris Database/10/right/
#   inflating: /content/imagenes/MMU Iris Database/10/right/fionar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/right/fionar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/right/fionar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/right/fionar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/10/right/fionar5.bmp
#    creating: /content/imagenes/MMU Iris Database/11/
#    creating: /content/imagenes/MMU Iris Database/11/left/
#   inflating: /content/imagenes/MMU Iris Database/11/left/hockl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/left/hockl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/left/hockl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/left/hockl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/left/hockl5.bmp
#    creating: /content/imagenes/MMU Iris Database/11/right/
#   inflating: /content/imagenes/MMU Iris Database/11/right/hockr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/right/hockr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/right/hockr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/right/hockr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/11/right/hockr5.bmp
#    creating: /content/imagenes/MMU Iris Database/12/
#    creating: /content/imagenes/MMU Iris Database/12/left/
#   inflating: /content/imagenes/MMU Iris Database/12/left/kelvinl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/left/kelvinl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/left/kelvinl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/left/kelvinl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/left/kelvinl5.bmp
#    creating: /content/imagenes/MMU Iris Database/12/right/
#   inflating: /content/imagenes/MMU Iris Database/12/right/kelvinr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/right/kelvinr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/right/kelvinr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/right/kelvinr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/12/right/kelvinr5.bmp
#    creating: /content/imagenes/MMU Iris Database/13/
#    creating: /content/imagenes/MMU Iris Database/13/left/
#   inflating: /content/imagenes/MMU Iris Database/13/left/lec_1.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/left/lecl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/left/lecl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/left/lecl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/left/lecl5.bmp
#    creating: /content/imagenes/MMU Iris Database/13/right/
#   inflating: /content/imagenes/MMU Iris Database/13/right/lecr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/right/lecr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/right/lecr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/right/lecr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/13/right/lecr5.bmp
#    creating: /content/imagenes/MMU Iris Database/14/
#    creating: /content/imagenes/MMU Iris Database/14/left/
#   inflating: /content/imagenes/MMU Iris Database/14/left/liujwl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/left/liujwl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/left/liujwl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/left/liujwl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/left/liujwl5.bmp
#    creating: /content/imagenes/MMU Iris Database/14/right/
#   inflating: /content/imagenes/MMU Iris Database/14/right/liujwr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/right/liujwr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/right/liujwr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/right/liujwr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/14/right/liujwr5.bmp
#    creating: /content/imagenes/MMU Iris Database/15/
#    creating: /content/imagenes/MMU Iris Database/15/left/
#   inflating: /content/imagenes/MMU Iris Database/15/left/lokel1.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/left/lokel2.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/left/lokel3.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/left/lokel4.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/left/lokel5.bmp
#    creating: /content/imagenes/MMU Iris Database/15/right/
#   inflating: /content/imagenes/MMU Iris Database/15/right/loker1.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/right/loker2.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/right/loker3.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/right/loker4.bmp
#   inflating: /content/imagenes/MMU Iris Database/15/right/loker5.bmp
#    creating: /content/imagenes/MMU Iris Database/16/
#    creating: /content/imagenes/MMU Iris Database/16/left/
#   inflating: /content/imagenes/MMU Iris Database/16/left/lowyfl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/left/lowyfl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/left/lowyfl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/left/lowyfl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/left/lowyfl5.bmp
#    creating: /content/imagenes/MMU Iris Database/16/right/
#   inflating: /content/imagenes/MMU Iris Database/16/right/lowyfr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/right/lowyfr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/right/lowyfr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/right/lowyfr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/16/right/lowyfr5.bmp
#    creating: /content/imagenes/MMU Iris Database/17/
#    creating: /content/imagenes/MMU Iris Database/17/left/
#   inflating: /content/imagenes/MMU Iris Database/17/left/lpjl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/left/lpjl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/left/lpjl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/left/lpjl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/left/lpjl5.bmp
#    creating: /content/imagenes/MMU Iris Database/17/right/
#   inflating: /content/imagenes/MMU Iris Database/17/right/lpjr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/right/lpjr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/right/lpjr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/right/lpjr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/17/right/lpjr5.bmp
#    creating: /content/imagenes/MMU Iris Database/18/
#    creating: /content/imagenes/MMU Iris Database/18/left/
#   inflating: /content/imagenes/MMU Iris Database/18/left/mahskl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/left/mahskl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/left/mahskl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/left/mahskl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/left/mahskl5.bmp
#    creating: /content/imagenes/MMU Iris Database/18/right/
#   inflating: /content/imagenes/MMU Iris Database/18/right/mahskr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/right/mahskr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/right/mahskr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/right/mahskr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/18/right/mahskr5.bmp
#    creating: /content/imagenes/MMU Iris Database/19/
#    creating: /content/imagenes/MMU Iris Database/19/left/
#   inflating: /content/imagenes/MMU Iris Database/19/left/maranl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/left/maranl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/left/maranl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/left/maranl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/left/maranl5.bmp
#    creating: /content/imagenes/MMU Iris Database/19/right/
#   inflating: /content/imagenes/MMU Iris Database/19/right/maranr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/right/maranr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/right/maranr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/right/maranr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/19/right/maranr5.bmp
#    creating: /content/imagenes/MMU Iris Database/2/
#    creating: /content/imagenes/MMU Iris Database/2/left/
#   inflating: /content/imagenes/MMU Iris Database/2/left/bryanl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/left/bryanl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/left/bryanl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/left/bryanl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/left/bryanl5.bmp
#    creating: /content/imagenes/MMU Iris Database/2/right/
#   inflating: /content/imagenes/MMU Iris Database/2/right/bryanr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/right/bryanr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/right/bryanr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/right/bryanr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/2/right/bryanr5.bmp
#    creating: /content/imagenes/MMU Iris Database/20/
#    creating: /content/imagenes/MMU Iris Database/20/left/
#   inflating: /content/imagenes/MMU Iris Database/20/left/masl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/left/masl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/left/masl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/left/masl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/left/masl5.bmp
#    creating: /content/imagenes/MMU Iris Database/20/right/
#   inflating: /content/imagenes/MMU Iris Database/20/right/masr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/right/masr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/right/masr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/right/masr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/20/right/masr5.bmp
#    creating: /content/imagenes/MMU Iris Database/21/
#    creating: /content/imagenes/MMU Iris Database/21/left/
#   inflating: /content/imagenes/MMU Iris Database/21/left/mazwanl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/left/mazwanl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/left/mazwanl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/left/mazwanl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/left/mazwanl5.bmp
#    creating: /content/imagenes/MMU Iris Database/21/right/
#   inflating: /content/imagenes/MMU Iris Database/21/right/mazwanr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/right/mazwanr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/right/mazwanr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/right/mazwanr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/21/right/mazwanr5.bmp
#    creating: /content/imagenes/MMU Iris Database/22/
#    creating: /content/imagenes/MMU Iris Database/22/left/
#   inflating: /content/imagenes/MMU Iris Database/22/left/mimil1.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/left/mimil2.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/left/mimil3.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/left/mimil4.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/left/mimil5.bmp
#    creating: /content/imagenes/MMU Iris Database/22/right/
#   inflating: /content/imagenes/MMU Iris Database/22/right/mimir1.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/right/mimir2.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/right/mimir3.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/right/mimir4.bmp
#   inflating: /content/imagenes/MMU Iris Database/22/right/mimir5.bmp
#    creating: /content/imagenes/MMU Iris Database/23/
#    creating: /content/imagenes/MMU Iris Database/23/left/
#   inflating: /content/imagenes/MMU Iris Database/23/left/minglil1.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/left/minglil2.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/left/minglil3.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/left/minglil4.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/left/minglil5.bmp
#    creating: /content/imagenes/MMU Iris Database/23/right/
#   inflating: /content/imagenes/MMU Iris Database/23/right/minglir1.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/right/minglir2.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/right/minglir3.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/right/minglir4.bmp
#   inflating: /content/imagenes/MMU Iris Database/23/right/minglir5.bmp
#    creating: /content/imagenes/MMU Iris Database/24/
#    creating: /content/imagenes/MMU Iris Database/24/left/
#   inflating: /content/imagenes/MMU Iris Database/24/left/ngkokwhyl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/left/ngkokwhyl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/left/ngkokwhyl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/left/ngkokwhyl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/left/ngkokwhyl5.bmp
#    creating: /content/imagenes/MMU Iris Database/24/right/
#   inflating: /content/imagenes/MMU Iris Database/24/right/ngkokwhyr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/right/ngkokwhyr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/right/ngkokwhyr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/right/ngkokwhyr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/24/right/ngkokwhyr5.bmp
#    creating: /content/imagenes/MMU Iris Database/25/
#    creating: /content/imagenes/MMU Iris Database/25/left/
#   inflating: /content/imagenes/MMU Iris Database/25/left/nkll1.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/left/nkll2.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/left/nkll3.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/left/nkll4.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/left/nkll5.bmp
#    creating: /content/imagenes/MMU Iris Database/25/right/
#   inflating: /content/imagenes/MMU Iris Database/25/right/nklr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/right/nklr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/right/nklr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/right/nklr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/25/right/nklr5.bmp
#    creating: /content/imagenes/MMU Iris Database/26/
#    creating: /content/imagenes/MMU Iris Database/26/left/
#   inflating: /content/imagenes/MMU Iris Database/26/left/norazal1.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/left/norazal2.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/left/norazal3.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/left/norazal4.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/left/norazal5.bmp
#    creating: /content/imagenes/MMU Iris Database/26/right/
#   inflating: /content/imagenes/MMU Iris Database/26/right/norazar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/right/norazar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/right/norazar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/right/norazar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/26/right/norazar5.bmp
#    creating: /content/imagenes/MMU Iris Database/27/
#    creating: /content/imagenes/MMU Iris Database/27/left/
#   inflating: /content/imagenes/MMU Iris Database/27/left/norsuhaidahl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/left/norsuhaidahl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/left/norsuhaidahl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/left/norsuhaidahl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/left/norsuhaidahl5.bmp
#    creating: /content/imagenes/MMU Iris Database/27/right/
#   inflating: /content/imagenes/MMU Iris Database/27/right/norsuhaidahr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/right/norsuhaidahr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/right/norsuhaidahr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/right/norsuhaidahr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/27/right/norsuhaidahr5.bmp
#    creating: /content/imagenes/MMU Iris Database/28/
#    creating: /content/imagenes/MMU Iris Database/28/left/
#   inflating: /content/imagenes/MMU Iris Database/28/left/ongbll1.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/left/ongbll2.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/left/ongbll3.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/left/ongbll4.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/left/ongbll5.bmp
#    creating: /content/imagenes/MMU Iris Database/28/right/
#   inflating: /content/imagenes/MMU Iris Database/28/right/ongblr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/right/ongblr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/right/ongblr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/right/ongblr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/28/right/ongblr5.bmp
#    creating: /content/imagenes/MMU Iris Database/29/
#    creating: /content/imagenes/MMU Iris Database/29/left/
#   inflating: /content/imagenes/MMU Iris Database/29/left/pcll1.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/left/pcll2.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/left/pcll3.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/left/pcll4.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/left/pcll5.bmp
#    creating: /content/imagenes/MMU Iris Database/29/right/
#   inflating: /content/imagenes/MMU Iris Database/29/right/pclr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/right/pclr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/right/pclr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/right/pclr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/29/right/pclr5.bmp
#    creating: /content/imagenes/MMU Iris Database/3/
#    creating: /content/imagenes/MMU Iris Database/3/left/
#   inflating: /content/imagenes/MMU Iris Database/3/left/chingycl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/left/chingycl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/left/chingycl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/left/chingycl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/left/chingycl5.bmp
#    creating: /content/imagenes/MMU Iris Database/3/right/
#   inflating: /content/imagenes/MMU Iris Database/3/right/chingycr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/right/chingycr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/right/chingycr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/right/chingycr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/3/right/chingycr5.bmp
#    creating: /content/imagenes/MMU Iris Database/30/
#    creating: /content/imagenes/MMU Iris Database/30/left/
#   inflating: /content/imagenes/MMU Iris Database/30/left/philipl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/left/philipl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/left/philipl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/left/philipl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/left/philipl5.bmp
#    creating: /content/imagenes/MMU Iris Database/30/right/
#   inflating: /content/imagenes/MMU Iris Database/30/right/philipr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/right/philipr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/right/philipr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/right/philipr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/30/right/philipr5.bmp
#    creating: /content/imagenes/MMU Iris Database/31/
#    creating: /content/imagenes/MMU Iris Database/31/left/
#   inflating: /content/imagenes/MMU Iris Database/31/left/roslil1.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/left/roslil2.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/left/roslil3.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/left/roslil4.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/left/roslil5.bmp
#    creating: /content/imagenes/MMU Iris Database/31/right/
#   inflating: /content/imagenes/MMU Iris Database/31/right/roslir1.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/right/roslir2.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/right/roslir3.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/right/roslir4.bmp
#   inflating: /content/imagenes/MMU Iris Database/31/right/roslir5.bmp
#    creating: /content/imagenes/MMU Iris Database/32/
#    creating: /content/imagenes/MMU Iris Database/32/left/
#   inflating: /content/imagenes/MMU Iris Database/32/left/salal1.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/left/salal2.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/left/salal3.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/left/salal4.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/left/salal5.bmp
#    creating: /content/imagenes/MMU Iris Database/32/right/
#   inflating: /content/imagenes/MMU Iris Database/32/right/salar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/right/salar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/right/salar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/right/salar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/32/right/salar5.bmp
#    creating: /content/imagenes/MMU Iris Database/33/
#    creating: /content/imagenes/MMU Iris Database/33/left/
#   inflating: /content/imagenes/MMU Iris Database/33/left/sarinal1.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/left/sarinal2.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/left/sarinal3.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/left/sarinal4.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/left/sarinal5.bmp
#    creating: /content/imagenes/MMU Iris Database/33/right/
#   inflating: /content/imagenes/MMU Iris Database/33/right/sarinar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/right/sarinar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/right/sarinar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/right/sarinar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/33/right/sarinar5.bmp
#    creating: /content/imagenes/MMU Iris Database/34/
#    creating: /content/imagenes/MMU Iris Database/34/left/
#   inflating: /content/imagenes/MMU Iris Database/34/left/sitil1.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/left/sitil2.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/left/sitil3.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/left/sitil4.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/left/sitil5.bmp
#    creating: /content/imagenes/MMU Iris Database/34/right/
#   inflating: /content/imagenes/MMU Iris Database/34/right/sitir1.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/right/sitir2.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/right/sitir3.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/right/sitir4.bmp
#   inflating: /content/imagenes/MMU Iris Database/34/right/sitir5.bmp
#    creating: /content/imagenes/MMU Iris Database/35/
#    creating: /content/imagenes/MMU Iris Database/35/left/
#   inflating: /content/imagenes/MMU Iris Database/35/left/suzailil1.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/left/suzailil2.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/left/suzailil3.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/left/suzailil4.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/left/suzailil5.bmp
#    creating: /content/imagenes/MMU Iris Database/35/right/
#   inflating: /content/imagenes/MMU Iris Database/35/right/suzailir1.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/right/suzailir2.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/right/suzailir3.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/right/suzailir4.bmp
#   inflating: /content/imagenes/MMU Iris Database/35/right/suzailir5.bmp
#    creating: /content/imagenes/MMU Iris Database/36/
#    creating: /content/imagenes/MMU Iris Database/36/left/
#   inflating: /content/imagenes/MMU Iris Database/36/left/tanwnl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/left/tanwnl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/left/tanwnl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/left/tanwnl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/left/tanwnl5.bmp
#    creating: /content/imagenes/MMU Iris Database/36/right/
#   inflating: /content/imagenes/MMU Iris Database/36/right/tanwnr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/right/tanwnr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/right/tanwnr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/right/tanwnr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/36/right/tanwnr5.bmp
#    creating: /content/imagenes/MMU Iris Database/37/
#    creating: /content/imagenes/MMU Iris Database/37/left/
#   inflating: /content/imagenes/MMU Iris Database/37/left/thomasl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/left/thomasl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/left/thomasl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/left/thomasl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/left/thomasl5.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/left/Thumbs.db
#    creating: /content/imagenes/MMU Iris Database/37/right/
#   inflating: /content/imagenes/MMU Iris Database/37/right/thomasr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/right/thomasr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/right/thomasr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/right/thomasr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/37/right/thomasr5.bmp
#    creating: /content/imagenes/MMU Iris Database/38/
#    creating: /content/imagenes/MMU Iris Database/38/left/
#   inflating: /content/imagenes/MMU Iris Database/38/left/tickl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/left/tickl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/left/tickl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/left/tickl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/left/tickl5.bmp
#    creating: /content/imagenes/MMU Iris Database/38/right/
#   inflating: /content/imagenes/MMU Iris Database/38/right/tickr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/right/tickr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/right/tickr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/right/tickr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/38/right/tickr5.bmp
#    creating: /content/imagenes/MMU Iris Database/39/
#    creating: /content/imagenes/MMU Iris Database/39/left/
#   inflating: /content/imagenes/MMU Iris Database/39/left/tingcyl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/left/tingcyl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/left/tingcyl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/left/tingcyl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/left/tingcyl5.bmp
#    creating: /content/imagenes/MMU Iris Database/39/right/
#   inflating: /content/imagenes/MMU Iris Database/39/right/tingcyr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/right/tingcyr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/right/tingcyr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/right/tingcyr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/39/right/tingcyr5.bmp
#    creating: /content/imagenes/MMU Iris Database/4/
#    creating: /content/imagenes/MMU Iris Database/4/left/
#    creating: /content/imagenes/MMU Iris Database/4/right/
#    creating: /content/imagenes/MMU Iris Database/40/
#    creating: /content/imagenes/MMU Iris Database/40/left/
#   inflating: /content/imagenes/MMU Iris Database/40/left/tonghll1.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/left/tonghll2.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/left/tonghll3.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/left/tonghll4.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/left/tonghll5.bmp
#    creating: /content/imagenes/MMU Iris Database/40/right/
#   inflating: /content/imagenes/MMU Iris Database/40/right/tonghlr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/right/tonghlr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/right/tonghlr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/right/tonghlr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/40/right/tonghlr5.bmp
#    creating: /content/imagenes/MMU Iris Database/41/
#    creating: /content/imagenes/MMU Iris Database/41/left/
#   inflating: /content/imagenes/MMU Iris Database/41/left/vimalal1.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/left/vimalal2.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/left/vimalal3.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/left/vimalal4.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/left/vimalal5.bmp
#    creating: /content/imagenes/MMU Iris Database/41/right/
#   inflating: /content/imagenes/MMU Iris Database/41/right/vimalar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/right/vimalar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/right/vimalar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/right/vimalar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/41/right/vimalar5.bmp
#    creating: /content/imagenes/MMU Iris Database/42/
#    creating: /content/imagenes/MMU Iris Database/42/left/
#   inflating: /content/imagenes/MMU Iris Database/42/left/Thumbs.db
#   inflating: /content/imagenes/MMU Iris Database/42/left/weecml1.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/left/weecml2.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/left/weecml3.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/left/weecml4.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/left/weecml5.bmp
#    creating: /content/imagenes/MMU Iris Database/42/right/
#   inflating: /content/imagenes/MMU Iris Database/42/right/weecmr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/right/weecmr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/right/weecmr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/right/weecmr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/42/right/weecmr5.bmp
#    creating: /content/imagenes/MMU Iris Database/43/
#    creating: /content/imagenes/MMU Iris Database/43/left/
#   inflating: /content/imagenes/MMU Iris Database/43/left/winl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/left/winl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/left/winl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/left/winl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/left/winl5.bmp
#    creating: /content/imagenes/MMU Iris Database/43/right/
#   inflating: /content/imagenes/MMU Iris Database/43/right/winr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/right/winr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/right/winr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/right/winr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/43/right/winr5.bmp
#    creating: /content/imagenes/MMU Iris Database/44/
#    creating: /content/imagenes/MMU Iris Database/44/left/
#   inflating: /content/imagenes/MMU Iris Database/44/left/yannl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/left/yannl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/left/yannl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/left/yannl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/left/yannl5.bmp
#    creating: /content/imagenes/MMU Iris Database/44/right/
#   inflating: /content/imagenes/MMU Iris Database/44/right/yannr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/right/yannr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/right/yannr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/right/yannr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/44/right/yannr5.bmp
#    creating: /content/imagenes/MMU Iris Database/45/
#    creating: /content/imagenes/MMU Iris Database/45/left/
#   inflating: /content/imagenes/MMU Iris Database/45/left/zaridahl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/left/zaridahl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/left/zaridahl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/left/zaridahl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/left/zaridahl5.bmp
#    creating: /content/imagenes/MMU Iris Database/45/right/
#   inflating: /content/imagenes/MMU Iris Database/45/right/zaridahr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/right/zaridahr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/right/zaridahr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/right/zaridahr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/45/right/zaridahr5.bmp
#    creating: /content/imagenes/MMU Iris Database/46/
#    creating: /content/imagenes/MMU Iris Database/46/left/
#   inflating: /content/imagenes/MMU Iris Database/46/left/Thumbs.db
#   inflating: /content/imagenes/MMU Iris Database/46/left/zulaikahl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/left/zulaikahl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/left/zulaikahl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/left/zulaikahl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/left/zulaikahl5.bmp
#    creating: /content/imagenes/MMU Iris Database/46/right/
#   inflating: /content/imagenes/MMU Iris Database/46/right/zulaikahr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/right/zulaikahr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/right/zulaikahr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/right/zulaikahr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/46/right/zulaikahr5.bmp
#    creating: /content/imagenes/MMU Iris Database/5/
#    creating: /content/imagenes/MMU Iris Database/5/left/
#   inflating: /content/imagenes/MMU Iris Database/5/left/chongpkl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/left/chongpkl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/left/chongpkl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/left/chongpkl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/left/chongpkl5.bmp
#    creating: /content/imagenes/MMU Iris Database/5/right/
#   inflating: /content/imagenes/MMU Iris Database/5/right/chongpkr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/right/chongpkr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/right/chongpkr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/right/chongpkr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/5/right/chongpkr5.bmp
#    creating: /content/imagenes/MMU Iris Database/6/
#    creating: /content/imagenes/MMU Iris Database/6/left/
#   inflating: /content/imagenes/MMU Iris Database/6/left/christinel1.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/left/christinel2.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/left/christinel3.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/left/christinel4.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/left/christinel5.bmp
#    creating: /content/imagenes/MMU Iris Database/6/right/
#   inflating: /content/imagenes/MMU Iris Database/6/right/christiner1.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/right/christiner2.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/right/christiner3.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/right/christiner4.bmp
#   inflating: /content/imagenes/MMU Iris Database/6/right/christiner5.bmp
#    creating: /content/imagenes/MMU Iris Database/7/
#    creating: /content/imagenes/MMU Iris Database/7/left/
#   inflating: /content/imagenes/MMU Iris Database/7/left/chualsl1.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/left/chualsl2.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/left/chualsl3.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/left/chualsl4.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/left/chualsl5.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/left/Thumbs.db
#    creating: /content/imagenes/MMU Iris Database/7/right/
#   inflating: /content/imagenes/MMU Iris Database/7/right/chualsr1.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/right/chualsr2.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/right/chualsr3.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/right/chualsr4.bmp
#   inflating: /content/imagenes/MMU Iris Database/7/right/chualsr5.bmp
#    creating: /content/imagenes/MMU Iris Database/8/
#    creating: /content/imagenes/MMU Iris Database/8/left/
#   inflating: /content/imagenes/MMU Iris Database/8/left/eugenehol1.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/left/eugenehol2.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/left/eugenehol3.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/left/eugenehol4.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/left/eugenehol5.bmp
#    creating: /content/imagenes/MMU Iris Database/8/right/
#   inflating: /content/imagenes/MMU Iris Database/8/right/eugenehor1.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/right/eugenehor2.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/right/eugenehor3.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/right/eugenehor4.bmp
#   inflating: /content/imagenes/MMU Iris Database/8/right/eugenehor5.bmp
#    creating: /content/imagenes/MMU Iris Database/9/
#    creating: /content/imagenes/MMU Iris Database/9/left/
#   inflating: /content/imagenes/MMU Iris Database/9/left/fatmal1.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/left/fatmal2.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/left/fatmal3.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/left/fatmal4.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/left/fatmal5.bmp
#    creating: /content/imagenes/MMU Iris Database/9/right/
#   inflating: /content/imagenes/MMU Iris Database/9/right/fatmar1.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/right/fatmar2.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/right/fatmar3.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/right/fatmar4.bmp
#   inflating: /content/imagenes/MMU Iris Database/9/right/fatmar5.bmp
#   inflating: /content/imagenes/MMU Iris Database/ReadMe.txt

# %%
im=cv2.imread('/content/MMU Iris Database/1/left/aeval2.bmp')
plt.imshow(im)

# %% [markdown]
# # Parte 1: Detección de Iris

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy.ndimage as nd
import time

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ffed6529-2967-480e-bc08-935bd02c3703" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ffed6529-2967-480e-bc08-935bd02c3703">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving iris1.jpg to iris1.jpg
# Saving iris2.jpg to iris2.jpg
# Saving iris3.jpg to iris3.jpg
# Saving irisCasia.jpg to irisCasia.jpg

# %% [markdown]
# ### Load Image

# %%
path = '/media/dela/1TB/A Universidad/Electrica/VIII Sem/Procesamiento Digital de Imagenes/IrisRec/IrisRecognition/IrisTestImages/'

#image = mpimg.imread(path + 'irisCasia.jpg')
image =cv2.imread('/content/irisCasia.jpg')
plt.imshow(image)

# %% [markdown]
# ### Pupil Detection
# Basado en el paper "A NOVEL APPROACH TO CIRCULAR EDGE DETECTION FOR IRIS IMAGE SEGMENTATION" de Shashidhara H R y Dr. A R Aswath.
#
# Aplica los primeros 4 pasos descritos en el método propuesto y luego, mediante búsqueda rápida, comenzando desde el centro de un eje, determina dos puntos de la circunferencia dada por los métodos previos para encontrar el centro en ese eje. Navega, luego, por el eje contrario en el determinado punto central para determinar el centro en el otro eje y el radio de la circunferencia.

# %%
'''Searches for two extreme points in a circumference in a given coordinate x or y. 
Returns the opposite coordinates of the two ends of the a chord parallel to the given axis'''

def borderPoints(image, theresold, coord, axis = 'y', border = 30):
    # image -> np.array, represents the border image
    # theresold -> float [0, 255], represents the theresold value to consider
    # coord -> integer, represents the row/column to navigate with
    # axis -> str, represents the axis to navigate with
    
    startPoint = None
    endPoint = None
    
    if axis == 'y':
        img = image[:, coord]
    else:
        img = image[coord, :]
        
    for i in range(border, img.size - border):
        if img[i] > theresold:
            startPoint = i
            break
        
    for j in range(img.size - border, border, -1):
        if img[j] > theresold:
            endPoint = j
            break
        
    return (startPoint, endPoint)

# %%
'''Returns the center coordinates of a circumference.'''

def centerDetect(image, theresold = 100, searchExactPoint = None, axis = 'y', found = False, searchLimit = 10):
    
    if searchExactPoint is None:
        size = (image.shape[1] if axis == 'y' else image.shape[0])
    else:
        startPoint, endPoint = borderPoints(image, theresold, searchExactPoint, axis)
        radii = (endPoint - startPoint)//2
        center = startPoint + radii
        return (center, radii, startPoint is not None, (startPoint, endPoint, searchExactPoint))
    
    # Buscar un punto de referencia en el borde de la circunferencia
    if not found:
        for i in range(2, searchLimit):
            step = size//i
            for j in range(1, i):
                other = step*j
                startPoint, endPoint = borderPoints(image, theresold, other, axis)
                if startPoint is not None:
                    found = True
                    break
        
    radii = (endPoint - startPoint)//2
    center = startPoint + radii
    return (center, radii, found, (startPoint, endPoint, other))

# %%
'''Applies the canny detector and center detect to find the iris center and radii.'''

def pupilDetector(img, theresold = 50):
    # img -> scipy.ndimage.ndarray, full color or grayscale image
    
    startTime = time.time()
    
    grayImage = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    
    thresh, BinaryImage = cv2.threshold(grayImage, theresold, 255, cv2.THRESH_BINARY)
    
    blur = cv2.GaussianBlur(BinaryImage,(5,5), 0) #Gaussian Smoothing, kernel 5x5, standard deviation (x, y) 0
    
    canny = cv2.Canny(blur, 400, 500) #Algoritmo de Canny para la deteccion de bordes, theresold (Hi/Lo) 100/200
    
    center_y, r, f, y_points = centerDetect(canny)
    detectedY = np.copy(canny)
    cv2.circle(detectedY, (y_points[2], y_points[0]), 3, (255, 255, 255), 3)
    cv2.circle(detectedY, (y_points[2], y_points[1]), 3, (255, 255, 255), 3)
    cv2.line(detectedY, (y_points[2], 0), (y_points[2], img.shape[0]), (255, 255, 255), 2)
    cv2.line(detectedY, (0, center_y), (img.shape[1], center_y), (255, 255, 255), 2)
    
    center_x, radii, f, x_points = centerDetect(canny, searchExactPoint = center_y, axis = 'x')
    detectedX = np.copy(canny)
    cv2.circle(detectedX, (x_points[0], x_points[2]), 3, (255, 255, 255), 3)
    cv2.circle(detectedX, (x_points[1], x_points[2]), 3, (255, 255, 255), 3)
    cv2.line(detectedX, (0, x_points[2]), (img.shape[1], x_points[2]), (255, 255, 255), 2)
    cv2.line(detectedX, (center_x, x_points[2]+radii+10), (center_x, x_points[2]-radii-10), (255, 255, 255), 2)
    
    pupil = np.copy(canny)
    cv2.circle(pupil, (center_x, center_y), radii, (255, 255, 255), 3)
    cv2.line(pupil, (center_x+radii//3, x_points[2]), (center_x-radii//3, x_points[2]), (255, 255, 255), 2)
    cv2.line(pupil, (center_x, x_points[2]+radii//3), (center_x, x_points[2]-radii//3), (255, 255, 255), 2)
    
    detectedPupil = np.copy(img)
    cv2.circle(detectedPupil, (center_x, center_y), radii, (255, 255, 255), 3)
    cv2.line(detectedPupil, (center_x+radii//3, x_points[2]), (center_x-radii//3, x_points[2]), (255, 255, 255), 2)
    cv2.line(detectedPupil, (center_x, x_points[2]+radii//3), (center_x, x_points[2]-radii//3), (255, 255, 255), 2)
    
    pupil_coords, pupil_radii = (center_x, center_y), radii
    
    print("Time (ms): {}".format((time.time()-startTime)*1000))
    
    return img, grayImage, BinaryImage, blur, canny, detectedY, detectedX, pupil, detectedPupil, pupil_coords, pupil_radii

img, grayImage, BinaryImage, blur, canny, detectedY, detectedX, pupil, detectedPupil, pupil_coords, pupil_radii = pupilDetector(image)
plt.imshow(detectedPupil, cmap = 'gray')
# Out:
# Time (ms): 50.3239631652832

# %%
fig=plt.figure(figsize=(15, 15))

fig.add_subplot(2, 4, 1)
imgplot = plt.imshow(grayImage, cmap = 'gray')
plt.title('Gray Scale Image')
fig.add_subplot(2, 4, 2)
imgplot = plt.imshow(BinaryImage, cmap = 'gray')
plt.title('Binary Image')
fig.add_subplot(2, 4, 3)
imgplot = plt.imshow(blur, cmap = 'gray')
plt.title('Gaussian Smoothing')
fig.add_subplot(2, 4, 4)
imgplot = plt.imshow(canny, cmap = 'gray')
plt.title('Border Detection')
fig.add_subplot(1, 4, 1)
imgplot = plt.imshow(detectedY, cmap = 'gray')
plt.title('Y Center Detection')
fig.add_subplot(1, 4, 2)
imgplot = plt.imshow(detectedX, cmap = 'gray')
plt.title('X Center Detection')
fig.add_subplot(1, 4, 3)
imgplot = plt.imshow(pupil, cmap = 'gray')
plt.title('Pupil')
fig.add_subplot(1, 4, 4)
imgplot = plt.imshow(detectedPupil, cmap = 'gray')
plt.title('Detected Pupil')
plt.show()

# %% [markdown]
# ### Iris Detection
# Basado en el paper "FAST AND ACCURATE IRIS SEGMENTATION BASED ON LINEAR BASIS FUNCTION ANDRANSAC" de Kai Wang y Yuntao Qian.
#
# Utiliza el método de búsqueda explicado en el artículo con la diferencia de que el espacio de búsqueda se reduce en base a los datos obtenidos anteriormente.
#
# A diferencia de el documento, ya se conoce un centro aproximado y el radio de la pupila, limitando los radios entre r_pupila y el maximo radio posible dentro de la imagen, definido como la mayor distancia entre el centro bruto y el borde de la imagen en los ejes horizontal y vertical. Esto permite reducir la búsqueda considerablemente, ya que no se navega pixel por pixel y radio por radio.
#
# Además, debido a que no todo el iris está visible, se define un ángulo con respecto a la horizontal en el cual se hará el barrido.

# %%
# irisPreprocessing = np.copy(detectedPupil)

# alpha = 0.25

# a_limit, b_limit = 110, 130
# table = np.zeros(256)
# spectre = range(a_limit, b_limit)

# m = a_limit*(1-alpha)
# beta = (255 - alpha*b_limit + m)/b_limit
# n = b_limit*(alpha - beta) + m

# for i in range(0, 255):
#     if i < a_limit:
#         table[i] = i
#     elif i > b_limit:
#         table[i] = beta*i + n
#     else: 
#         table[i] = 0#alpha*i + m

# for i in range(img.shape[0]):
#     for j in range(img.shape[1]):
#         irisPreprocessing[i, j] = table[irisPreprocessing[i,j]]
        
# irisPreprocessing = irisPreprocessing[:,:,0]
        
# plt.imshow(irisPreprocessing, cmap = 'gray')

# %%
### MEJORAR EFICIENCIA ###
### REVISAR, min_size = 40 es demasiado ###
'''Given a pupil, detects the iris using the integrodifferential operator and LBF + Ransac.'''

def irisDetector(img, pupil_coords, pupil_radii, margin = 5, min_iris_size = 40, angle = np.pi/6):
    # image -> np.array, represents the grayscale image
    # pupil_coords -> integer tuple, pupil raw center
    # pupil_radii -> integer, pupil raw radii
    # margin -> integer, search box size around the raw center
    # min_iris_size -> integer, minimum distance between iris and pupil radii
    
    startTime = time.time()
    
    x_max, y_max = img.shape
    maxRadii = min(pupil_coords[0], x_max - pupil_coords[0], 
                   y_max, y_max - pupil_coords[1]) - margin - 1
    
    buffer, X, Y, R = 0, 0, 0, 0
    
    arr = np.zeros((2*margin + 1, 2*margin + 1, maxRadii - pupil_radii - min_iris_size), np.int8)
    
    for r in range(pupil_radii + min_iris_size, maxRadii): #Iris DEBE caber en el cuadro
        y_range = int(np.sqrt(r**2 * (1 - np.cos(2*angle))))
        r_max = r
        for i in range(pupil_coords[0] - margin, pupil_coords[0] + margin):
            for j in range(pupil_coords[1] - margin, pupil_coords[1] + margin):
                suma, cnt = 0, 0
                for y in range(-y_range, y_range):
                    x = int(np.sqrt(r**2 - y**2))
                    suma += img[x + i, y + j] + img[i - x, y + j]
                    cnt += 2
                arr[i - pupil_coords[0] + margin, j - pupil_coords[1] + margin, r - pupil_radii - min_iris_size] = suma/cnt
    
    argmax = np.zeros((arr.shape[2], 2))
    maxVal = np.zeros(arr.shape[2])
    
    for r in range(1, arr.shape[2]):
        arr_r = arr[:,:,r] - arr[:,:,r - 1]
        argPos = np.argmax(arr_r)
        argmax[r] = (argPos//arr_r.shape[0], int(argPos%arr_r.shape[0]))
        maxVal[r] = arr_r[int(argmax[r][0]), int(argmax[r][1])]
    
    absoluteMax = np.argmax(maxVal)
    x_pos, y_pos = tuple(argmax[absoluteMax])
    
    print("Time (s): {}".format(time.time()-startTime))
        
    return (int(x_pos) + pupil_coords[0] - margin, 
            int(y_pos) + pupil_coords[1] - margin, 
            absoluteMax + pupil_radii + min_iris_size)
                
iris = irisDetector(grayImage, pupil_coords, pupil_radii)
# Out:
# <ipython-input-9-eaeeac8ba379>:29: RuntimeWarning: overflow encountered in ubyte_scalars
#   suma += img[x + i, y + j] + img[i - x, y + j]
# Time (s): 0.39391613006591797

# %%
center_x, center_y, radii = iris
detectedIris = np.copy(detectedPupil)
cv2.circle(detectedIris, (center_x, center_y), radii, (255, 255, 255), 3)
plt.imshow(detectedIris, cmap = 'gray')

# %% [markdown]
# ### Iris Cleaning
#
# Mask: https://stackoverflow.com/questions/44865023/how-can-i-create-a-circular-mask-for-a-numpy-array

# %%
def create_circular_mask(h, w, center, radius, internal = False):
    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)
    mask = dist_from_center <= radius
    if internal:
        mask = dist_from_center >= radius
    return mask

# %%
mask_iris = create_circular_mask(grayImage.shape[0], grayImage.shape[1], (center_x, center_y), radii)
mask_pupil = create_circular_mask(grayImage.shape[0], grayImage.shape[1], pupil_coords, pupil_radii, internal = True)
mask = mask_pupil & mask_iris
irisImage = np.copy(grayImage) * mask
plt.imshow(irisImage, cmap = 'gray')

# %%
thresh, binaryIrisMask1 = cv2.threshold(irisImage, 100, 255, cv2.THRESH_BINARY)
thresh, binaryIrisMask2 = cv2.threshold(irisImage, 170, 255, cv2.THRESH_BINARY_INV)
binaryIrisMask = binaryIrisMask1 & binaryIrisMask2
plt.imshow(binaryIrisMask, cmap = 'gray')

# %%
plt.imshow(irisImage*binaryIrisMask, cmap = 'gray')
